# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
lenna = cv2.imread('Lenna_(test_image).png')

# %%
# Out:
# (512, 512)

# %%
lenna.reshape((512*512, 3)) / 256
# Out:
# array([[0.48828125, 0.53515625, 0.8828125 ],
#        [0.48828125, 0.53515625, 0.8828125 ],
#        [0.51953125, 0.53515625, 0.87109375],
#        ...,
#        [0.30859375, 0.2734375 , 0.69921875],
#        [0.31640625, 0.27734375, 0.70703125],
#        [0.31640625, 0.2890625 , 0.72265625]])

# %%
lenna.reshape((512*512, 3))[:,1].shape
# Out:
# (262144,)

# %%
512 ** 2
# Out:
# 262144

# %%
plt_image.shape
# Out:
# (512, 512, 3)

# %%
plt_image = cv2.cvtColor(lenna, cv2.COLOR_BGR2RGB) #cv2.COLOR_BGR2HSV
plt_image = plt_image.reshape((512*512, 3))
plt_color = plt_image / 255
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(plt_image[:,0], plt_image[:,1], plt_image[:,2], c=plt_color)
plt.show()
